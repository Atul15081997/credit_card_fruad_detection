# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('UCI_Credit_Card.csv')

# %%
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
data.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...    88004.0    31237.0    15980.0    8500.0   20000.0
# 29996     -1  ...     8979.0     5190.0        0.0    1837.0    3526.0
# 29997     -1  ...    20878.0    20582.0    19357.0       0.0       0.0
# 29998      0  ...    52774.0    11855.0    48944.0   85900.0    3409.0
# 29999      0  ...    36535.0    32428.0    15313.0    2078.0    1800.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
sns.countplot(data['SEX'] , hue=data['default.payment.next.month'])
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='count'>

# %%
sns.countplot(data['EDUCATION'],hue=data['default.payment.next.month'])
# Out:
# <AxesSubplot:xlabel='EDUCATION', ylabel='count'>

# %%
sns.countplot(data['MARRIAGE'] ,hue=data['default.payment.next.month'])
# Out:
# <AxesSubplot:xlabel='MARRIAGE', ylabel='count'>

# %%
sns.countplot(data['AGE'] , hue=data['default.payment.next.month'])
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='count'>

# %%
plt.hist(data['AGE'])
# Out:
# (array([5.127e+03, 8.261e+03, 6.514e+03, 4.812e+03, 2.606e+03, 1.836e+03,
#         6.280e+02, 1.710e+02, 4.000e+01, 5.000e+00]),
#  array([21. , 26.8, 32.6, 38.4, 44.2, 50. , 55.8, 61.6, 67.4, 73.2, 79. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(data.corr(),annot=True,cmap='Blues',linewidths=1)
# Out:
# <AxesSubplot:>

# %%
data.shape
print('number of rows', data.shape[0])
print('number of column', data.shape[1])
# Out:
# number of rows 30000
# number of column 25

# %%
data.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
data.duplicated().any()
#hence no duplicate value present in the data set
# Out:
# False

# %%
data['default.payment.next.month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default.payment.next.month, dtype: int64

# %%
sns.countplot(data['default.payment.next.month'])
# Out:
# <AxesSubplot:xlabel='default.payment.next.month', ylabel='count'>

# %%
X=data.drop('default.payment.next.month',axis=1)
y=data['default.payment.next.month']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20 ,random_state=40)

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)
# Out:
# 0.7803333333333333

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_pred2=dt.predict(X_test)
accuracy_score(y_test,y_pred2)
# Out:
# 0.7238333333333333

# %%
from sklearn.ensemble import RandomForestClassifier
rm=RandomForestClassifier()
rm.fit(X_train,y_train)
y_pred3=rm.predict(X_test)
accuracy_score(y_test,y_pred3)
# Out:
# 0.824

# %%
 final_data=pd.DataFrame({'models':['LR','DT','RM'],'Accuracy':[accuracy_score(y_test,y_pred1)*100,
                                                    accuracy_score(y_test,y_pred2)*100,
                                                   accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   models   Accuracy
# 0     LR  78.033333
# 1     DT  72.383333
# 2     RM  82.400000

# %%
sns.barplot(final_data['models'],final_data['Accuracy'])
# Out:
# <AxesSubplot:xlabel='models', ylabel='Accuracy'>

# %%
import joblib
joblib.dump(rm,'Credit_card_fraud_detection')
# Out:
# ['Credit_card_fraud_detection']

# %%
model=joblib.load('Credit_card_fraud_detection')

# %%
from tkinter import *
def show_entry_fields():
    v1=float(e1.get())
    v2=float(e2.get())
    v3=float(e3.get())
    v4=float(e4.get())
    v5=float(e5.get())
    v6=float(e6.get())

    v7=float(e7.get())
    v8=float(e8.get())
    v9=float(e9.get())
    v10=float(e10.get())
    v11=float(e11.get())
    v12=float(e12.get())

    v13=float(e13.get())
    v14=float(e14.get())
    v15=float(e15.get())
    v16=float(e16.get())
    v17=float(e17.get())
    v18=float(e18.get())


    v19=float(e19.get())
    v20=float(e20.get())
    v21=float(e21.get())
    v22=float(e22.get())
    v23=float(e23.get())
    v24=float(e24.get())



    model=joblib.load('Credit_card_fraud_detection')
    y_pred = model.predict([[v1,v2,v3,v4,v5,v6,v7,v8,v9,v10,v11,v12,v13,v14,v15,v16,v17,v18,
                                v19,v20,v21,v22,v23,v24]])
    list1=[v1,v2,v3,v4,v5,v6,v7,v8,v9,v10,v11,v12,v13,v14,v15,v16,v17,v18,
                                v19,v20,v21,v22,v23,v24]

    result = []
    if y_pred ==0:

        result.append("Normal Transcation")
    else:

        result.append("Fraudulent Transcation")
    print("######################################")
    print("Credit Card Fraud Detection System", result)
    print("######################################")



    Label(master, text="Final Prediction from the model - credit card fraud detection").grid(row=25)
    Label(master, text=result).grid(row=25)



master = Tk()
master.title("Credit Card Fraud Detection System")


label = Label(master, text = "Credit Card Fraud Detection System"
                          , bg = "black", fg = "white",width = 30).grid(row=0,columnspan=2)


Label(master, text="Enter ID").grid(row=1)
Label(master, text="Enter value of LIMIT_BAL ").grid(row=2)
Label(master, text="Enter SEX ,Gender (1=male, 2=female)").grid(row=3)
Label(master, text="EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)").grid(row=4)
Label(master, text="Marital status:(1=married, 2=single, 3=others)").grid(row=5)
Label(master, text="AGE: Age in years").grid(row=6)

Label(master, text=''' Repayment status in September ( 1=payment delay for one month,
      2=payment delay for two months...9=payment delay for nine months and above)''').grid(row=7)
Label(master, text="Repayment status in August, 2005 (scale same as above").grid(row=8)
Label(master, text="Repayment status in July, 2005 (scale same as above)").grid(row=9)
Label(master, text=" Repayment status in June, 2005 (scale same as above)").grid(row=10)
Label(master, text="Repayment status in May, 2005 (scale same as above)").grid(row=11)
Label(master, text="Repayment status in April, 2005 (scale same as above)").grid(row=12)

Label(master, text="Amount of bill statement in September, 2005 (NT dollar)").grid(row=13)
Label(master, text="Amount of bill statement in aug, 2005 (NT dollar)").grid(row=14)
Label(master, text="Amount of bill statement in july, 2005 (NT dollar)").grid(row=15)
Label(master, text="Amount of bill statement in june, 2005 (NT dollar)").grid(row=16)
Label(master, text="Amount of bill statement in may, 2005 (NT dollar)").grid(row=17)
Label(master, text="Amount of bill statement in april, 2005 (NT dollar)").grid(row=18)

Label(master, text="Amount of previous payment in September, 2005 (NT dollar)").grid(row=19)
Label(master, text="Amount of previous payment in aug, 2005 (NT dollar)").grid(row=20)
Label(master, text="Amount of previous payment in july, 2005 (NT dollar)").grid(row=21)
Label(master, text="Amount of previous payment in june, 2005 (NT dollar)").grid(row=22)
Label(master, text="Amount of previous payment in may, 2005 (NT dollar)").grid(row=23)
Label(master, text="Amount of previous payment in april, 2005 (NT dollar)").grid(row=24)

e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)

e7 = Entry(master)
e8 = Entry(master)
e9 = Entry(master)
e10 = Entry(master)
e11 = Entry(master)
e12 = Entry(master)

e13 = Entry(master)
e14 = Entry(master)
e15 = Entry(master)
e16 = Entry(master)
e17 = Entry(master)
e18= Entry(master)

e19 = Entry(master)
e20 = Entry(master)
e21 = Entry(master)
e22 = Entry(master)
e23= Entry(master)
e24 = Entry(master)

e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)

e7.grid(row=7, column=1)
e8.grid(row=8, column=1)
e9.grid(row=9, column=1)
e10.grid(row=10, column=1)
e11.grid(row=11, column=1)
e12.grid(row=12, column=1)


e13.grid(row=13, column=1)
e14.grid(row=14, column=1)
e15.grid(row=15, column=1)
e16.grid(row=16, column=1)
e17.grid(row=17, column=1)
e18.grid(row=18, column=1)


e19.grid(row=19, column=1)
e20.grid(row=20, column=1)
e21.grid(row=21, column=1)
e22.grid(row=22, column=1)
e23.grid(row=23, column=1)
e24.grid(row=24, column=1)
 
Button(master, text='Predict', command=show_entry_fields).grid(row=25, column=1, sticky=W, pady=4)

mainloop( )
# Out:
# ######################################
# Credit Card Fraud Detection System ['Normal Transcation']
# ######################################
# ######################################
# Credit Card Fraud Detection System ['Normal Transcation']
# ######################################
# ######################################
# Credit Card Fraud Detection System ['Normal Transcation']
# ######################################
# ######################################
# Credit Card Fraud Detection System ['Normal Transcation']
# ######################################
